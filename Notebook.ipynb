# %%
from sqlalchemy.orm import sessionmaker
import matplotlib.pyplot as plt
from engine import engine


Session = sessionmaker(bind=engine)
session = Session()

# %%
from display_cases import display_all_coronadata_singleplot

display_all_coronadata_singleplot(session, ['Peru'])

# %%
from display_confirmed import display_confirmed

display_confirmed(session, ['Mexico', 'Cuba'])

# %%
from display_avg_quality import display_average_air_quality

display_average_air_quality(session, ['Germany'])
